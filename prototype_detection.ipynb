# %%
from mtcnn.mtcnn import MTCNN
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
import os
import cv2 as cv

# %%
def get_faces(image_path):
    image = plt.imread(image_path)
    return detector.detect_faces(image)

def draw_img_with_box(faces, image_path):
    image = plt.imread(image_path)
    fig, ax = plt.subplots(1, 1, figsize=(10, 6))
    for face in faces:
        x, y, w, h = face['box']
        rect = Rectangle((x, y), w, h, color='green', fill=False)
        ax.add_patch(rect)
    ax.imshow(image);
    
def save_faces_as_imgs(faces, image_path):
    image = plt.imread(image_path)
    if 'extracted_faces' not in os.listdir():
        os.mkdir('extracted_faces')
    folder_name = path.split('/')[-1].split('.')[0]
    os.mkdir(f'extracted_faces/{folder_name}')
    for i, face in enumerate(faces):
        x, y, w, h = faces[i]['box']
        extracted = image[y:y+h, x:x+w]
        extracted = cv.cvtColor(extracted, cv.COLOR_RGB2BGR)
        cv.imwrite(f'extracted_faces/{folder_name}/{i}.png', extracted)

# %%
detector = MTCNN()

# %%
path = 'test/2.JPG'

# %%
faces = get_faces(path)

# %%
draw_img_with_box(faces, path)
save_faces_as_imgs(faces, path)
